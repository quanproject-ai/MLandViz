# %%
import model_v2 as ml
# Out:
# /Users/quanha/Documents/git/mlenv/lib/python3.12/site-packages/sklearn/model_selection/_split.py:776: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# /Users/quanha/Documents/git/mlenv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/quanha/Documents/git/mlenv/lib/python3.12/site-packages/sklearn/model_selection/_split.py:776: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# ...

# %%
import model_v2 as ml
# Out:
# /Users/quanha/Documents/git/mlenv/lib/python3.12/site-packages/sklearn/model_selection/_split.py:776: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
#                 Model Name           mse        mae        rmse  \
# 2  DecisionTreeRegressor()    885.679057  10.937936   29.760361
# 4    KNeighborsRegressor()   1505.257790  15.196482   38.797652
# 3     ExtraTreeRegressor()    933.688102  11.923166   30.556310
# 1             GaussianNB()   3715.627946  38.682044   60.955951
# 5           SGDRegressor()  23413.936460  93.807546  153.016131
# 0            LassoLarsCV()  20851.004650  94.561197  144.398770
#
#    average score validation R^2 of 5  traing time elapsed
# 2                           0.988752             0.373199
# 4                           0.986377             0.124889
# 3                           0.986053             0.129857
# 1                           0.966968             0.612449
# ...
